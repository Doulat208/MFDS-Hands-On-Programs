# %%
import pandas as pd

print("hello")
# Out:
# hello

# %%
 a = input("Enter value")
 print(a)
# Out:
# Enter value34
# 34

# %%
a = int(5)
print(a)
# Out:
# 5

# %%
a = b= c = "hello"
print(a,b,c)
# Out:
# hello hello hello

# %%
a = input("enter a number : ")
b = input("enter a Strint : ")
c = input("enter a Float : ")
print(a,b,c)
# Out:
# enter a number23
# enter a Strinttfi
# enter a Float8.5
# 23 tfi 8.5

# %%
2
a = int(input("Enter a number : "))
b = int(input("Enter a number : "))
c = int(input("Enter a number : "))
d = int(input("Enter a number : "))
sum = a+b+c+d
sum
# Out:
# Enter a number : 20
# Enter a number : 20
# Enter a number : 20
# Enter a number : 20
# 80

# %%
from ast import Str
a = str(input("Enter a numsting : "))
b = str(input("Enter a numsting : "))
c = str(input("Enter a numsting : "))
d = str(input("Enter a numsting : "))
sum = a+b+c+d
sum
# Out:
# Enter a numsting : hello
# Enter a numsting : my
# Enter a numsting : friend
# Enter a numsting : krishna
# 'hellomyfriendkrishna'

# %%
list1 = [0,1,2,3]
print(list1[3])
# Out:
# 3

# %%
tuple1 = (1,2.5,'ch',4)
print(tuple1)
tuple1[1]
# Out:
# (1, 2.5, 'ch', 4)
# 2.5

# %%
set1 = {1,2,3,3,3,4,4,5}
print(set1)
# set1[3]  error
# Out:
# {1, 2, 3, 4, 5}

# %%
a = int(input())
b = int(input())
if(a > b):
  print(a)
elif(b>a):
  print(b)
else:
  print("both are same")
# Out:
# 23
# 23
# both are same

# %%
a,b = 3, 4
print(a, b)
a,b = b,a
print(a, b)
# Out:
# 3 4
# 4 3

# %%
i = 1
while i< 6:
  print(i,end =" ")
  i=i+1
# Out:
# 1 2 3 4 5

# %%
i = 1
while i<=10:
  if i%2 == 0:
    print(i, end= " ")
  i=i+1
# Out:
# 2 4 6 8 10

# %%
def add(a,b):
  print(a+b)
add(2,3)
# Out:
# 5

# %%
import pandas as pd
mydata = {  'car': ["bmw", "thar","volvo"], 'passings': [3,4,8]}
myvar = pd.DataFrame(mydata)
print(mydata)
print(myvar)
# Out:
# {'car': ['bmw', 'thar', 'volvo'], 'passings': [3, 4, 8]}
#      car  passings
# 0    bmw         3
# 1   thar         4
# 2  volvo         8
