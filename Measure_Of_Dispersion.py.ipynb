# %%
import pandas as pd
import matplotlib.pyplot as pit
url='https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)
# print(df)
mean_value = df['Fare'].mean()
median_value = df['Fare'].median()
mode_value = df['Fare'].mode()
print(f"mean value- {mean_value}")
print(f"median value- {median_value}")
print(f"mode value- {mode_value}")
# Out:
# mean value- 32.204207968574636
# median value- 14.4542
# mode value- 0    8.05
# Name: Fare, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as pit
url='https://s3.amazonaws.com/hackerday.datascience/49/Test_u94Q5KV.csv'
df = pd.read_csv(url)
df
mean_value = df['Item_MRP'].mean()
median_value = df['Item_MRP'].median()
mode_value = df['Item_MRP'].mode()
std_value = df['Item_MRP'].std()
print(f"mean value- {mean_value}")
print(f"median value- {median_value}")
print(f"mode value- {mode_value}")
print(f"Standard value- {std_value}")
# Out:
# mean value- 141.02327340256994
# median value- 141.4154
# mode value- 0    57.0614
# Name: Item_MRP, dtype: float64
# Standard value- 61.809090595947225
